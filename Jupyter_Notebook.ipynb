# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# # In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# # Objectives:
# List of popular languages of Data Science
# *R
# *Python
# *Julia

# %% [markdown]
# # Some of the popular languages that Data Scientists use are:
# 1.Python
# 2.SQL
# 3.R
# 4.Julia

# %% [markdown]
# # Some of the commonly used libraries used by Data Scientists include:
# 1.Pandas
# 2.NumPy
# 3.Seaborn
# 4.Matplotlib

# %% [markdown]
# |# Data Science Tools |
# |.....................|
# | Juypter Notebook |
# | R-Studio |
# | Apache Zeppelin |

# %% [markdown]
# ### Few examples of evaluating arithematic expressions in Python
# Addition: 5 + 7
# Subtraction: 19 - 13
# Multiplication: 12 * 17
# Exponent: 5 ** 3

# %%
# Simple arithematic expression to first Multiply then Add
(3*4)+5
# Out:
# 17

# %%
#Convert minutes to hours
time_in_minutes = 200
time_in_hours = time_in_minutes / 60  #Convert minutes to hours
print(time_in_hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# RITU RAJ
