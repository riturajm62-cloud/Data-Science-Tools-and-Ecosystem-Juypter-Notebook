# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# # In this notebook Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# # Some of the popular languages that Data Scientist use are:
# 1.Python
# 2.SQL
# 3.R
# 4.Julia
# 5.Scala

# %% [markdown]
# # Objectives:
# List of popular languages for Data Science
# -R
# -SQL
# -Python

# %% [markdown]
# # Some of the commonly used libraries used by Data Scientists include:
# 1.Pandas
# 2.NumPy
# 3.Matplotlib
# 4.Seaborn

# %% [markdown]
# | # Data Science Tools|
# | ....................|
# | Juypter Notebook |
# | R-Studio |
# | Apache Zeppelin |

# %% [markdown]
# ### Below are few examples of evaluating arithematic expression in Python
# Addition: 5 + 7
# Subtraction: 8 - 4
# Multiplication: 13 * 9
# Exponent: 8 ** 2

# %%
# Simple arithematic expression to first multiply then add
(3*4)+5
# Out:
# 17

# %%
# convert minute to hours by dividing by 60
time_in_minutes = 200
time_in_hours = time_in_minutes / 60
print(time_in_hours)
# Out:
# 3.3333333333333335

# %%
## Author
RITU RAJ
